# %%
import sys
sys.path.append("../Lib")
import utils as ut
import pandas as pd
import scipy as sp
import operator
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import normalize
from sklearn.metrics.pairwise import cosine_similarity

import warnings
warnings.filterwarnings("ignore")

# %%
df_model = pd.read_csv('../Data/csv/model.csv', encoding='utf-8')

# %% [markdown]
# ### User Recommendation
# En este modelo vamos a aplicar el filtro usuario-elemento, es decir, tomar un usuario, encontrar usuarios similares y recomendar elementos que les hayan gustado a esos usuarios similares. En este caso, la entrada es un usuario y la salida es una lista de juegos recomendados para ese usuario.

# %%
df_model
# Out:
#          item_id                       item_name  genres            user_id  \
# 0         282010            Carmageddon Max Pack  Action           UTNerd24
# 1         282010            Carmageddon Max Pack  Action           saint556
# 2         282010            Carmageddon Max Pack  Action             chidvd
# 3         282010            Carmageddon Max Pack  Action             aerpub
# 4         282010            Carmageddon Max Pack  Action  76561198001688490
# ...          ...                             ...     ...                ...
# 3382334       80  Counter-Strike: Condition Zero  Action           jazzecks
# 3382335       80  Counter-Strike: Condition Zero  Action             lachwe
# 3382336       80  Counter-Strike: Condition Zero  Action       danebuchanan
# 3382337       80  Counter-Strike: Condition Zero  Action  76561198208507532
# 3382338       80  Counter-Strike: Condition Zero  Action  76561198312638244
#
#          rating
# 0             1
# 1             5
# 2             5
# 3             1
# 4             5
# ...         ...
# 3382334       5
# 3382335       5
# 3382336       5
# 3382337       1
# 3382338       5
#
# [3382339 rows x 5 columns]

# %%
df_mod_user = df_model[['user_id', 'item_name', 'rating']]
df_mod_user.drop_duplicates(inplace=True)
df_mod_user
# Out:
#                    user_id                       item_name  rating
# 0                 UTNerd24            Carmageddon Max Pack       1
# 1                 saint556            Carmageddon Max Pack       5
# 2                   chidvd            Carmageddon Max Pack       5
# 3                   aerpub            Carmageddon Max Pack       1
# 4        76561198001688490            Carmageddon Max Pack       5
# ...                    ...                             ...     ...
# 3382334           jazzecks  Counter-Strike: Condition Zero       5
# 3382335             lachwe  Counter-Strike: Condition Zero       5
# 3382336       danebuchanan  Counter-Strike: Condition Zero       5
# 3382337  76561198208507532  Counter-Strike: Condition Zero       1
# 3382338  76561198312638244  Counter-Strike: Condition Zero       5
#
# [1146428 rows x 3 columns]

# %%
# Vamos a crear una matriz que contenga el 'user_id' como índices, los nombres de los elementos como columnas y la 'calificación' como valores.
u_matrix = df_mod_user.pivot_table(index=['user_id'], columns=['item_name'], values='rating')
u_matrix
# Out:
# item_name     ! That Bastard Is Trying To Steal Our Gold !  \
# user_id
# --000--                                                NaN
# --ace--                                                NaN
# --ionex--                                              NaN
# -2SV-vuLB-Kg                                           NaN
# -Azsael-                                               NaN
# ...                                                    ...
# zwanzigdrei                                            NaN
# zy0705                                                 NaN
# zynxgameth                                             NaN
# zyr0n1c                                                NaN
# zzoptimuszz                                            NaN
#
# item_name     "Glow Ball" - The billiard puzzle game  #SelfieTennis  $1 Ride  \
# user_id
# --000--                                          NaN            NaN      NaN
# --ace--                                          NaN            NaN      NaN
# --ionex--                                        NaN            NaN      NaN
# -2SV-vuLB-Kg                                     NaN            NaN      NaN
# -Azsael-                                         NaN            NaN      NaN
# ...                                              ...            ...      ...
# zwanzigdrei                                      NaN            NaN      NaN
# zy0705                                           NaN            NaN      NaN
# zynxgameth                                       NaN            NaN      NaN
# zyr0n1c                                          NaN            NaN      NaN
# zzoptimuszz                                      NaN            NaN      NaN
#
# item_name     'n Verlore Verstand  001 Game Creator  0RBITALIS  \
# user_id
# --000--                       NaN               NaN        NaN
# --ace--                       NaN               NaN        NaN
# --ionex--                     NaN               NaN        NaN
# -2SV-vuLB-Kg                  NaN               NaN        NaN
# -Azsael-                      NaN               NaN        NaN
# ...                           ...               ...        ...
# zwanzigdrei                   NaN               NaN        NaN
# zy0705                        NaN               NaN        NaN
# zynxgameth                    NaN               NaN        NaN
# zyr0n1c                       NaN               NaN        NaN
# zzoptimuszz                   NaN               NaN        NaN
#
# item_name     1 Moment Of Time: Silentville  1,000 Heads Among the Trees  \
# user_id
# --000--                                 NaN                          NaN
# --ace--                                 NaN                          NaN
# --ionex--                               NaN                          NaN
# -2SV-vuLB-Kg                            NaN                          NaN
# -Azsael-                                NaN                          NaN
# ...                                     ...                          ...
# zwanzigdrei                             NaN                          NaN
# zy0705                                  NaN                          NaN
# zynxgameth                              NaN                          NaN
# zyr0n1c                                 NaN                          NaN
# zzoptimuszz                             NaN                          NaN
#
# item_name     10 Second Ninja  ...  rymdkapsel  sZone-Online  samurai_jazz  \
# user_id                        ...
# --000--                   NaN  ...         NaN           3.0           NaN
# --ace--                   NaN  ...         NaN           NaN           NaN
# --ionex--                 NaN  ...         NaN           NaN           NaN
# -2SV-vuLB-Kg              NaN  ...         NaN           NaN           NaN
# -Azsael-                  NaN  ...         NaN           NaN           NaN
# ...                       ...  ...         ...           ...           ...
# zwanzigdrei               NaN  ...         NaN           NaN           NaN
# zy0705                    NaN  ...         NaN           NaN           NaN
# zynxgameth                NaN  ...         NaN           NaN           NaN
# zyr0n1c                   NaN  ...         NaN           NaN           NaN
# zzoptimuszz               NaN  ...         NaN           NaN           NaN
#
# item_name     simian.interface++  stratO  the static speaks my name  theBlu  \
# user_id
# --000--                      NaN     NaN                        NaN     NaN
# --ace--                      NaN     NaN                        NaN     NaN
# --ionex--                    NaN     NaN                        NaN     NaN
# -2SV-vuLB-Kg                 NaN     NaN                        NaN     NaN
# -Azsael-                     NaN     NaN                        NaN     NaN
# ...                          ...     ...                        ...     ...
# zwanzigdrei                  NaN     NaN                        NaN     NaN
# zy0705                       NaN     NaN                        NaN     NaN
# zynxgameth                   NaN     NaN                        NaN     NaN
# zyr0n1c                      NaN     NaN                        NaN     NaN
# zzoptimuszz                  NaN     NaN                        NaN     NaN
#
# item_name     theHunter: Primal  侠客风云传(Tale of Wuxia)  \
# user_id
# --000--                     NaN                   NaN
# --ace--                     NaN                   NaN
# --ionex--                   NaN                   NaN
# -2SV-vuLB-Kg                NaN                   NaN
# -Azsael-                    NaN                   NaN
# ...                         ...                   ...
# zwanzigdrei                 NaN                   NaN
# zy0705                      NaN                   NaN
# zynxgameth                  NaN                   NaN
# zyr0n1c                     NaN                   NaN
# zzoptimuszz                 NaN                   NaN
#
# item_name     軒轅劍外傳穹之扉(The Gate of Firmament)
# user_id
# --000--                                   NaN
# --ace--                                   NaN
# --ionex--                                 NaN
# -2SV-vuLB-Kg                              NaN
# -Azsael-                                  NaN
# ...                                       ...
# zwanzigdrei                               NaN
# zy0705                                    NaN
# zynxgameth                                NaN
# zyr0n1c                                   NaN
# zzoptimuszz                               NaN
#
# [22532 rows x 6941 columns]

# %%
# Para ahorrar memoria, trabajemos con una muestra de los datos
random_rows = 5000
u_matrix_sample = u_matrix.sample(n=random_rows, random_state=42)

# %%
# Vamos a normalizar los valores del marco de datos. La normalización ajusta las calificaciones de un usuario, se centran en cero y se escalan según su variabilidad.
scaler = MinMaxScaler()
umatrix_norm = pd.DataFrame(scaler.fit_transform(u_matrix_sample), columns=u_matrix_sample.columns, index=u_matrix_sample.index)

# Las columnas que contienen solo cero o no tienen calificación se eliminan, los espacios en blanco se llenan con 0.
umatrix_norm.fillna(0, inplace=True)
umatrix_norm = umatrix_norm.T
umatrix_norm = umatrix_norm.loc[:, (umatrix_norm != 0).any(axis=0)]
umatrix_norm
# Out:
# user_id                                       bhim_a_saurus  \
# item_name
# ! That Bastard Is Trying To Steal Our Gold !            0.0
# "Glow Ball" - The billiard puzzle game                  0.0
# #SelfieTennis                                           0.0
# $1 Ride                                                 0.0
# 'n Verlore Verstand                                     0.0
# ...                                                     ...
# the static speaks my name                               0.0
# theBlu                                                  0.0
# theHunter: Primal                                       0.0
# 侠客风云传(Tale of Wuxia)                                    0.0
# 軒轅劍外傳穹之扉(The Gate of Firmament)                         0.0
#
# user_id                                       76561198062325995  fatkings  \
# item_name
# ! That Bastard Is Trying To Steal Our Gold !                0.0       0.0
# "Glow Ball" - The billiard puzzle game                      0.0       0.0
# #SelfieTennis                                               0.0       0.0
# $1 Ride                                                     0.0       0.0
# 'n Verlore Verstand                                         0.0       0.0
# ...                                                         ...       ...
# the static speaks my name                                   0.0       0.0
# theBlu                                                      0.0       0.0
# theHunter: Primal                                           0.0       0.0
# 侠客风云传(Tale of Wuxia)                                        0.0       0.0
# 軒轅劍外傳穹之扉(The Gate of Firmament)                             0.0       0.0
#
# user_id                                       76561198087282941  \
# item_name
# ! That Bastard Is Trying To Steal Our Gold !                0.0
# "Glow Ball" - The billiard puzzle game                      0.0
# #SelfieTennis                                               0.0
# $1 Ride                                                     0.0
# 'n Verlore Verstand                                         0.0
# ...                                                         ...
# the static speaks my name                                   0.0
# theBlu                                                      0.0
# theHunter: Primal                                           0.0
# 侠客风云传(Tale of Wuxia)                                        0.0
# 軒轅劍外傳穹之扉(The Gate of Firmament)                             0.0
#
# user_id                                       76561198059870308  flix141  \
# item_name
# ! That Bastard Is Trying To Steal Our Gold !                0.0      0.0
# "Glow Ball" - The billiard puzzle game                      0.0      0.0
# #SelfieTennis                                               0.0      0.0
# $1 Ride                                                     0.0      0.0
# 'n Verlore Verstand                                         0.0      0.0
# ...                                                         ...      ...
# the static speaks my name                                   0.0      0.0
# theBlu                                                      0.0      0.0
# theHunter: Primal                                           0.0      0.0
# 侠客风云传(Tale of Wuxia)                                        0.0      0.0
# 軒轅劍外傳穹之扉(The Gate of Firmament)                             0.0      0.0
#
# user_id                                       76561198044865157  marhan  \
# item_name
# ! That Bastard Is Trying To Steal Our Gold !                0.0     0.0
# "Glow Ball" - The billiard puzzle game                      0.0     0.0
# #SelfieTennis                                               0.0     0.0
# $1 Ride                                                     0.0     0.0
# 'n Verlore Verstand                                         0.0     0.0
# ...                                                         ...     ...
# the static speaks my name                                   0.0     0.0
# theBlu                                                      0.0     0.0
# theHunter: Primal                                           0.0     0.0
# 侠客风云传(Tale of Wuxia)                                        0.0     0.0
# 軒轅劍外傳穹之扉(The Gate of Firmament)                             0.0     0.0
#
# user_id                                       76561198001115538  IronMoose  \
# item_name
# ! That Bastard Is Trying To Steal Our Gold !                0.0        0.0
# "Glow Ball" - The billiard puzzle game                      0.0        0.0
# #SelfieTennis                                               0.0        0.0
# $1 Ride                                                     0.0        0.0
# 'n Verlore Verstand                                         0.0        0.0
# ...                                                         ...        ...
# the static speaks my name                                   0.0        0.0
# theBlu                                                      0.0        0.0
# theHunter: Primal                                           0.0        0.0
# 侠客风云传(Tale of Wuxia)                                        0.0        0.0
# 軒轅劍外傳穹之扉(The Gate of Firmament)                             0.0        0.0
#
# user_id                                       ...  kinit  76561198141851819  \
# item_name                                     ...
# ! That Bastard Is Trying To Steal Our Gold !  ...    0.0                0.0
# "Glow Ball" - The billiard puzzle game        ...    0.0                0.0
# #SelfieTennis                                 ...    0.0                0.0
# $1 Ride                                       ...    0.0                0.0
# 'n Verlore Verstand                           ...    0.0                0.0
# ...                                           ...    ...                ...
# the static speaks my name                     ...    0.0                0.0
# theBlu                                        ...    0.0                0.0
# theHunter: Primal                             ...    0.0                0.0
# 侠客风云传(Tale of Wuxia)                          ...    0.0                0.0
# 軒轅劍外傳穹之扉(The Gate of Firmament)               ...    0.0                0.0
#
# user_id                                       Orphaned  FakeTaxiServicesAU  \
# item_name
# ! That Bastard Is Trying To Steal Our Gold !       0.0                 0.0
# "Glow Ball" - The billiard puzzle game             0.0                 0.0
# #SelfieTennis                                      0.0                 0.0
# $1 Ride                                            0.0                 0.0
# 'n Verlore Verstand                                0.0                 0.0
# ...                                                ...                 ...
# the static speaks my name                          0.0                 0.0
# theBlu                                             0.0                 0.0
# theHunter: Primal                                  0.0                 0.0
# 侠客风云传(Tale of Wuxia)                               0.0                 0.0
# 軒轅劍外傳穹之扉(The Gate of Firmament)                    0.0                 0.0
#
# user_id                                       76561198072465460  \
# item_name
# ! That Bastard Is Trying To Steal Our Gold !                0.0
# "Glow Ball" - The billiard puzzle game                      0.0
# #SelfieTennis                                               0.0
# $1 Ride                                                     0.0
# 'n Verlore Verstand                                         0.0
# ...                                                         ...
# the static speaks my name                                   0.0
# theBlu                                                      0.0
# theHunter: Primal                                           0.0
# 侠客风云传(Tale of Wuxia)                                        0.0
# 軒轅劍外傳穹之扉(The Gate of Firmament)                             0.0
#
# user_id                                       MessWithNoOne  Failkills007  \
# item_name
# ! That Bastard Is Trying To Steal Our Gold !            0.0           0.0
# "Glow Ball" - The billiard puzzle game                  0.0           0.0
# #SelfieTennis                                           0.0           0.0
# $1 Ride                                                 0.0           0.0
# 'n Verlore Verstand                                     0.0           0.0
# ...                                                     ...           ...
# the static speaks my name                               0.0           0.0
# theBlu                                                  0.0           0.0
# theHunter: Primal                                       0.0           0.0
# 侠客风云传(Tale of Wuxia)                                    0.0           0.0
# 軒轅劍外傳穹之扉(The Gate of Firmament)                         0.0           0.0
#
# user_id                                       76561198114969651  tomtoth  \
# item_name
# ! That Bastard Is Trying To Steal Our Gold !                0.0      0.0
# "Glow Ball" - The billiard puzzle game                      0.0      0.0
# #SelfieTennis                                               0.0      0.0
# $1 Ride                                                     0.0      0.0
# 'n Verlore Verstand                                         0.0      0.0
# ...                                                         ...      ...
# the static speaks my name                                   0.0      0.0
# theBlu                                                      0.0      0.0
# theHunter: Primal                                           0.0      0.5
# 侠客风云传(Tale of Wuxia)                                        0.0      0.0
# 軒轅劍外傳穹之扉(The Gate of Firmament)                             0.0      0.0
#
# user_id                                       76561197979007418
# item_name
# ! That Bastard Is Trying To Steal Our Gold !                0.0
# "Glow Ball" - The billiard puzzle game                      0.0
# #SelfieTennis                                               0.0
# $1 Ride                                                     0.0
# 'n Verlore Verstand                                         0.0
# ...                                                         ...
# the static speaks my name                                   0.0
# theBlu                                                      0.0
# theHunter: Primal                                           0.0
# 侠客风云传(Tale of Wuxia)                                        0.0
# 軒轅劍外傳穹之扉(The Gate of Firmament)                             0.0
#
# [6941 rows x 4006 columns]

# %% [markdown]
# Estamos convirtiendo umatrix_norm a un formato de matriz dispersa para reducir la memoria utilizada y mejorar la eficiencia en el manejo de grandes conjuntos de datos, especialmente cuando la mayoría de los valores de la matriz son ceros. Luego también normalizamos la matriz dispersa.

# %%
um_sparse = sp.sparse.csr_matrix(umatrix_norm.values)
um_sparse
# Out:
# <6941x4006 sparse matrix of type '<class 'numpy.float64'>'
# 	with 194371 stored elements in Compressed Sparse Row format>

# %%
um_sparse_normalized = normalize(um_sparse)

# Ahora, aplicamos el modelo de similitud del coseno a la matriz dispersa normalizada transpuesta
user_similarity = cosine_similarity(um_sparse_normalized.T)

# Ahora, vamos a guardar la matriz del modelo en un marco de datos para poder usarla en nuestra función.
user_sim_df = pd.DataFrame(user_similarity, index = umatrix_norm.columns, columns = umatrix_norm.columns)

user_sim_df
# Out:
# user_id            bhim_a_saurus  76561198062325995  fatkings  \
# user_id
# bhim_a_saurus           1.000000           0.004569  0.027144
# 76561198062325995       0.004569           1.000000  0.011623
# fatkings                0.027144           0.011623  1.000000
# 76561198087282941       0.014563           0.017213  0.089673
# 76561198059870308       0.009962           0.128583  0.048787
# ...                          ...                ...       ...
# MessWithNoOne           0.017793           0.015442  0.042597
# Failkills007            0.127120           0.005058  0.031343
# 76561198114969651       0.046260           0.008095  0.026740
# tomtoth                 0.071285           0.005893  0.004640
# 76561197979007418       0.022207           0.006627  0.002295
#
# user_id            76561198087282941  76561198059870308   flix141  \
# user_id
# bhim_a_saurus               0.014563           0.009962  0.017109
# 76561198062325995           0.017213           0.128583  0.051515
# fatkings                    0.089673           0.048787  0.030273
# 76561198087282941           1.000000           0.021808  0.027765
# 76561198059870308           0.021808           1.000000  0.032977
# ...                              ...                ...       ...
# MessWithNoOne               0.086399           0.021733  0.050672
# Failkills007                0.002394           0.046563  0.040232
# 76561198114969651           0.012513           0.060251  0.032282
# tomtoth                     0.004033           0.027092  0.002698
# 76561197979007418           0.002493           0.000000  0.010170
#
# user_id            76561198044865157    marhan  76561198001115538  IronMoose  \
# user_id
# bhim_a_saurus               0.032447  0.042184           0.081065   0.079740
# 76561198062325995           0.005247  0.000000           0.010833   0.003111
# fatkings                    0.008513  0.049842           0.130623   0.036960
# 76561198087282941           0.054552  0.014846           0.048999   0.019943
# 76561198059870308           0.016720  0.010927           0.044304   0.010528
# ...                              ...       ...                ...        ...
# MessWithNoOne               0.004986  0.005557           0.068235   0.016234
# Failkills007                0.018877  0.066428           0.049477   0.089743
# 76561198114969651           0.014267  0.025634           0.036455   0.049860
# tomtoth                     0.001612  0.008094           0.010509   0.027955
# 76561197979007418           0.025501  0.037488           0.013429   0.005997
#
# user_id            ...     kinit  76561198141851819  Orphaned  \
# user_id            ...
# bhim_a_saurus      ...  0.121768           0.020920  0.037355
# 76561198062325995  ...  0.001303           0.012860  0.001524
# fatkings           ...  0.031279           0.023614  0.024358
# 76561198087282941  ...  0.001120           0.012566  0.007245
# 76561198059870308  ...  0.002228           0.054390  0.004750
# ...                ...       ...                ...       ...
# MessWithNoOne      ...  0.002467           0.035534  0.035943
# Failkills007       ...  0.104754           0.007209  0.029139
# 76561198114969651  ...  0.035099           0.040122  0.012548
# tomtoth            ...  0.012948           0.001351  0.039522
# 76561197979007418  ...  0.005004           0.002539  0.001238
#
# user_id            FakeTaxiServicesAU  76561198072465460  MessWithNoOne  \
# user_id
# bhim_a_saurus                0.045373           0.009045       0.017793
# 76561198062325995            0.051340           0.029986       0.015442
# fatkings                     0.008083           0.016496       0.042597
# 76561198087282941            0.011813           0.012101       0.086399
# 76561198059870308            0.051925           0.069932       0.021733
# ...                               ...                ...            ...
# MessWithNoOne                0.027982           0.029496       1.000000
# Failkills007                 0.025613           0.004518       0.002327
# 76561198114969651            0.034865           0.005691       0.005841
# tomtoth                      0.005497           0.000572       0.005487
# 76561197979007418            0.002930           0.005920       0.012548
#
# user_id            Failkills007  76561198114969651   tomtoth  \
# user_id
# bhim_a_saurus          0.127120           0.046260  0.071285
# 76561198062325995      0.005058           0.008095  0.005893
# fatkings               0.031343           0.026740  0.004640
# 76561198087282941      0.002394           0.012513  0.004033
# 76561198059870308      0.046563           0.060251  0.027092
# ...                         ...                ...       ...
# MessWithNoOne          0.002327           0.005841  0.005487
# Failkills007           1.000000           0.027156  0.016817
# 76561198114969651      0.027156           1.000000  0.019395
# tomtoth                0.016817           0.019395  1.000000
# 76561197979007418      0.014786           0.005541  0.000000
#
# user_id            76561197979007418
# user_id
# bhim_a_saurus               0.022207
# 76561198062325995           0.006627
# fatkings                    0.002295
# 76561198087282941           0.002493
# 76561198059870308           0.000000
# ...                              ...
# MessWithNoOne               0.012548
# Failkills007                0.014786
# 76561198114969651           0.005541
# tomtoth                     0.000000
# 76561197979007418           1.000000
#
# [4006 rows x 4006 columns]

# %% [markdown]
# Crear la función de recomendación de elementos de usuario.

# %%
def similar_user_recs(user: str):
    # Comprobar si el usuario está presente en las columnas umatrix_norm (si no, devolver un mensaje)
    if user not in umatrix_norm.columns:
        return 'No hay datos disponibles para el usuario {}'.format(user)
    
    # Obtener los usuarios más similares al usuario dado
    sim_users = user_sim_df.sort_values(by=user, ascending=False).index[1:11]
    
    best = []  # Lista para almacenar los artículos mejor valorados por usuarios similares
    most_common = {}  # Diccionario para contar cuantas veces se recomienda cada artículo
    
    # Para cada usuario similar, busque el artículo mejor calificado y agréguelo a la lista de "mejores"
    for i in sim_users:
        max_score = umatrix_norm.loc[:, i].max()
        best.extend(umatrix_norm[umatrix_norm.loc[:, i] == max_score].index.tolist())
           
    # Cuenta cuántas veces se recomienda cada artículo
    for j in best:
        most_common[j] = most_common.get(j, 0) + 1
    
    # Ordenar elementos por frecuencia de recomendación en orden descendente
    sorted_list = sorted(most_common.items(), key=operator.itemgetter(1), reverse=True)
    
    # Devolver los 5 artículos más recomendados
    return 'Usuarios similares a {}: también les gustó'.format(user), sorted_list[:5]

# %%
# Comprobando la función
similar_user_recs('tomtoth')
# Out:
# ('Usuarios similares a tomtoth: también les gustó',
#  [('Unturned', 9),
#   ('Counter-Strike: Global Offensive', 8),
#   ('PAYDAY 2', 8),
#   ("Garry's Mod", 7),
#   ('Left 4 Dead 2', 7)])

# %% [markdown]
# ### Item Recomendation
# Este modelo de modelo tendrá una relación ítem-ítem, es decir, se toma un ítem, en base a qué tan similar sea ese ítem al resto, se recomiendan similares. Aquí la entrada es un juego y la salida es una lista de juegos recomendados.

# %%
df_mod_game = df_model[['item_id', 'item_name', 'genres']]
df_mod_game.drop_duplicates(inplace=True)
df_mod_game
# Out:
#          item_id                       item_name    genres
# 0         282010            Carmageddon Max Pack    Action
# 55        282010            Carmageddon Max Pack     Indie
# 110       282010            Carmageddon Max Pack    Racing
# 165           70                       Half-Life    Action
# 2866        1640  Disciples II: Gallean's Return  Strategy
# ...          ...                             ...       ...
# 3379988       30                   Day of Defeat    Action
# 3380548   200980                     Geneforge 2  Strategy
# 3380555   200980                     Geneforge 2       RPG
# 3380562   200980                     Geneforge 2     Indie
# 3380569       80  Counter-Strike: Condition Zero    Action
#
# [18854 rows x 3 columns]

# %%
# Creamos una nueva columna 'genre_tag' con valores 1.
df_mod_game['genre_tag'] = 1 
df_mod_game
# Out:
#          item_id                       item_name    genres  genre_tag
# 0         282010            Carmageddon Max Pack    Action          1
# 55        282010            Carmageddon Max Pack     Indie          1
# 110       282010            Carmageddon Max Pack    Racing          1
# 165           70                       Half-Life    Action          1
# 2866        1640  Disciples II: Gallean's Return  Strategy          1
# ...          ...                             ...       ...        ...
# 3379988       30                   Day of Defeat    Action          1
# 3380548   200980                     Geneforge 2  Strategy          1
# 3380555   200980                     Geneforge 2       RPG          1
# 3380562   200980                     Geneforge 2     Indie          1
# 3380569       80  Counter-Strike: Condition Zero    Action          1
#
# [18854 rows x 4 columns]

# %%
# Creamos un marco de datos auxiliar 'df_id' para extraer el id_item para nuestra función de recomendación.
df_id = df_mod_game[['item_id', 'item_name']].drop_duplicates()

df_id
# Out:
#          item_id                        item_name
# 0         282010             Carmageddon Max Pack
# 165           70                        Half-Life
# 2866        1640   Disciples II: Gallean's Return
# 2902        1630  Disciples II: Rise of the Elves
# 2918        3800                    Advent Rising
# ...          ...                              ...
# 3379810    40990                            Mafia
# 3379946   259340               Chicken Shoot Gold
# 3379988       30                    Day of Defeat
# 3380548   200980                      Geneforge 2
# 3380569       80   Counter-Strike: Condition Zero
#
# [6941 rows x 2 columns]

# %%
# Vamos a crear una matriz que contenga los 'item_names' como índices, los 'genres' como columnas y la 'genre_tag' como valores.

# %%
g_matrix = df_mod_game.pivot_table(index='item_name', columns='genres', values='genre_tag', fill_value=0)
g_matrix
# Out:
# genres                                        Action  Action RPG  \
# item_name
# ! That Bastard Is Trying To Steal Our Gold !     1.0         0.0
# "Glow Ball" - The billiard puzzle game           0.0         0.0
# #SelfieTennis                                    0.0         0.0
# $1 Ride                                          1.0         0.0
# 'n Verlore Verstand                              0.0         0.0
# ...                                              ...         ...
# the static speaks my name                        0.0         0.0
# theBlu                                           0.0         0.0
# theHunter: Primal                                1.0         0.0
# 侠客风云传(Tale of Wuxia)                             0.0         0.0
# 軒轅劍外傳穹之扉(The Gate of Firmament)                  0.0         0.0
#
# genres                                        Action-Adventure  Adventure  \
# item_name
# ! That Bastard Is Trying To Steal Our Gold !               0.0        1.0
# "Glow Ball" - The billiard puzzle game                     0.0        0.0
# #SelfieTennis                                              0.0        0.0
# $1 Ride                                                    0.0        0.0
# 'n Verlore Verstand                                        0.0        1.0
# ...                                                        ...        ...
# the static speaks my name                                  0.0        1.0
# theBlu                                                     0.0        1.0
# theHunter: Primal                                          0.0        1.0
# 侠客风云传(Tale of Wuxia)                                       0.0        1.0
# 軒轅劍外傳穹之扉(The Gate of Firmament)                            0.0        0.0
#
# genres                                        Aliens  Animation & Modeling  \
# item_name
# ! That Bastard Is Trying To Steal Our Gold !     0.0                   0.0
# "Glow Ball" - The billiard puzzle game           0.0                   0.0
# #SelfieTennis                                    0.0                   0.0
# $1 Ride                                          0.0                   0.0
# 'n Verlore Verstand                              0.0                   0.0
# ...                                              ...                   ...
# the static speaks my name                        0.0                   0.0
# theBlu                                           0.0                   0.0
# theHunter: Primal                                0.0                   0.0
# 侠客风云传(Tale of Wuxia)                             0.0                   0.0
# 軒轅劍外傳穹之扉(The Gate of Firmament)                  0.0                   0.0
#
# genres                                        Anime  Arcade  Arena Shooter  \
# item_name
# ! That Bastard Is Trying To Steal Our Gold !    0.0     0.0            0.0
# "Glow Ball" - The billiard puzzle game          0.0     0.0            0.0
# #SelfieTennis                                   0.0     0.0            0.0
# $1 Ride                                         0.0     0.0            0.0
# 'n Verlore Verstand                             0.0     0.0            0.0
# ...                                             ...     ...            ...
# the static speaks my name                       0.0     0.0            0.0
# theBlu                                          0.0     0.0            0.0
# theHunter: Primal                               0.0     0.0            0.0
# 侠客风云传(Tale of Wuxia)                            0.0     0.0            0.0
# 軒轅劍外傳穹之扉(The Gate of Firmament)                 0.0     0.0            0.0
#
# genres                                        Atmospheric  ...  Violent  \
# item_name                                                  ...
# ! That Bastard Is Trying To Steal Our Gold !          0.0  ...      0.0
# "Glow Ball" - The billiard puzzle game                0.0  ...      0.0
# #SelfieTennis                                         0.0  ...      0.0
# $1 Ride                                               0.0  ...      0.0
# 'n Verlore Verstand                                   1.0  ...      0.0
# ...                                                   ...  ...      ...
# the static speaks my name                             0.0  ...      0.0
# theBlu                                                0.0  ...      0.0
# theHunter: Primal                                     0.0  ...      0.0
# 侠客风云传(Tale of Wuxia)                                  0.0  ...      0.0
# 軒轅劍外傳穹之扉(The Gate of Firmament)                       0.0  ...      0.0
#
# genres                                        Visual Novel  Voxel  \
# item_name
# ! That Bastard Is Trying To Steal Our Gold !           0.0    0.0
# "Glow Ball" - The billiard puzzle game                 0.0    0.0
# #SelfieTennis                                          0.0    0.0
# $1 Ride                                                0.0    0.0
# 'n Verlore Verstand                                    1.0    0.0
# ...                                                    ...    ...
# the static speaks my name                              0.0    0.0
# theBlu                                                 0.0    0.0
# theHunter: Primal                                      0.0    0.0
# 侠客风云传(Tale of Wuxia)                                   0.0    0.0
# 軒轅劍外傳穹之扉(The Gate of Firmament)                        0.0    0.0
#
# genres                                        Walking Simulator  War  Wargame  \
# item_name
# ! That Bastard Is Trying To Steal Our Gold !                0.0  0.0      0.0
# "Glow Ball" - The billiard puzzle game                      0.0  0.0      0.0
# #SelfieTennis                                               0.0  0.0      0.0
# $1 Ride                                                     0.0  0.0      0.0
# 'n Verlore Verstand                                         1.0  0.0      0.0
# ...                                                         ...  ...      ...
# the static speaks my name                                   0.0  0.0      0.0
# theBlu                                                      0.0  0.0      0.0
# theHunter: Primal                                           0.0  0.0      0.0
# 侠客风云传(Tale of Wuxia)                                        0.0  0.0      0.0
# 軒轅劍外傳穹之扉(The Gate of Firmament)                             0.0  0.0      0.0
#
# genres                                        Web Publishing  Werewolves  \
# item_name
# ! That Bastard Is Trying To Steal Our Gold !             0.0         0.0
# "Glow Ball" - The billiard puzzle game                   0.0         0.0
# #SelfieTennis                                            0.0         0.0
# $1 Ride                                                  0.0         0.0
# 'n Verlore Verstand                                      0.0         0.0
# ...                                                      ...         ...
# the static speaks my name                                0.0         0.0
# theBlu                                                   0.0         0.0
# theHunter: Primal                                        0.0         0.0
# 侠客风云传(Tale of Wuxia)                                     0.0         0.0
# 軒轅劍外傳穹之扉(The Gate of Firmament)                          0.0         0.0
#
# genres                                        Zombies  e-sports
# item_name
# ! That Bastard Is Trying To Steal Our Gold !      0.0       0.0
# "Glow Ball" - The billiard puzzle game            0.0       0.0
# #SelfieTennis                                     0.0       0.0
# $1 Ride                                           0.0       0.0
# 'n Verlore Verstand                               0.0       0.0
# ...                                               ...       ...
# the static speaks my name                         0.0       0.0
# theBlu                                            0.0       0.0
# theHunter: Primal                                 0.0       0.0
# 侠客风云传(Tale of Wuxia)                              0.0       0.0
# 軒轅劍外傳穹之扉(The Gate of Firmament)                   0.0       0.0
#
# [6941 rows x 186 columns]

# %% [markdown]
# Vamos a convertir g_matrix_sample a un formato de matriz dispersa para reducir la memoria utilizada y mejorar la eficiencia en el manejo de grandes conjuntos de datos, especialmente cuando la mayoría de los valores de la matriz son ceros.

# %%
game_sparse = sp.sparse.csr_matrix(g_matrix.values)

# Aplicar el modelo de similitud del coseno a la matriz sparse.
game_similarity = cosine_similarity(game_sparse)

# Guardando el modelo matrix en un nuev dataframe
game_sim_df = pd.DataFrame(game_similarity, index = g_matrix.index, columns = g_matrix.index)
game_sim_df
# Out:
# item_name                                     ! That Bastard Is Trying To Steal Our Gold !  \
# item_name
# ! That Bastard Is Trying To Steal Our Gold !                                      1.000000
# "Glow Ball" - The billiard puzzle game                                            0.500000
# #SelfieTennis                                                                     0.288675
# $1 Ride                                                                           0.866025
# 'n Verlore Verstand                                                               0.353553
# ...                                                                                    ...
# the static speaks my name                                                         0.500000
# theBlu                                                                            0.612372
# theHunter: Primal                                                                 0.577350
# 侠客风云传(Tale of Wuxia)                                                              0.447214
# 軒轅劍外傳穹之扉(The Gate of Firmament)                                                   0.000000
#
# item_name                                     "Glow Ball" - The billiard puzzle game  \
# item_name
# ! That Bastard Is Trying To Steal Our Gold !                                0.500000
# "Glow Ball" - The billiard puzzle game                                      1.000000
# #SelfieTennis                                                               0.577350
# $1 Ride                                                                     0.577350
# 'n Verlore Verstand                                                         0.235702
# ...                                                                              ...
# the static speaks my name                                                   0.250000
# theBlu                                                                      0.408248
# theHunter: Primal                                                           0.000000
# 侠客风云传(Tale of Wuxia)                                                        0.447214
# 軒轅劍外傳穹之扉(The Gate of Firmament)                                             0.000000
#
# item_name                                     #SelfieTennis   $1 Ride  \
# item_name
# ! That Bastard Is Trying To Steal Our Gold !       0.288675  0.866025
# "Glow Ball" - The billiard puzzle game             0.577350  0.577350
# #SelfieTennis                                      1.000000  0.333333
# $1 Ride                                            0.333333  1.000000
# 'n Verlore Verstand                                0.272166  0.272166
# ...                                                     ...       ...
# the static speaks my name                          0.288675  0.288675
# theBlu                                             0.471405  0.471405
# theHunter: Primal                                  0.000000  0.333333
# 侠客风云传(Tale of Wuxia)                               0.000000  0.258199
# 軒轅劍外傳穹之扉(The Gate of Firmament)                    0.000000  0.000000
#
# item_name                                     'n Verlore Verstand  \
# item_name
# ! That Bastard Is Trying To Steal Our Gold !             0.353553
# "Glow Ball" - The billiard puzzle game                   0.235702
# #SelfieTennis                                            0.272166
# $1 Ride                                                  0.272166
# 'n Verlore Verstand                                      1.000000
# ...                                                           ...
# the static speaks my name                                0.235702
# theBlu                                                   0.384900
# theHunter: Primal                                        0.136083
# 侠客风云传(Tale of Wuxia)                                     0.210819
# 軒轅劍外傳穹之扉(The Gate of Firmament)                          0.000000
#
# item_name                                     001 Game Creator  0RBITALIS  \
# item_name
# ! That Bastard Is Trying To Steal Our Gold !               0.0   0.353553
# "Glow Ball" - The billiard puzzle game                     0.0   0.353553
# #SelfieTennis                                              0.0   0.408248
# $1 Ride                                                    0.0   0.408248
# 'n Verlore Verstand                                        0.0   0.166667
# ...                                                        ...        ...
# the static speaks my name                                  0.0   0.353553
# theBlu                                                     0.0   0.577350
# theHunter: Primal                                          0.0   0.408248
# 侠客风云传(Tale of Wuxia)                                       0.0   0.316228
# 軒轅劍外傳穹之扉(The Gate of Firmament)                            0.0   0.000000
#
# item_name                                     1 Moment Of Time: Silentville  \
# item_name
# ! That Bastard Is Trying To Steal Our Gold !                       0.707107
# "Glow Ball" - The billiard puzzle game                             0.353553
# #SelfieTennis                                                      0.408248
# $1 Ride                                                            0.408248
# 'n Verlore Verstand                                                0.333333
# ...                                                                     ...
# the static speaks my name                                          0.707107
# theBlu                                                             0.577350
# theHunter: Primal                                                  0.408248
# 侠客风云传(Tale of Wuxia)                                               0.316228
# 軒轅劍外傳穹之扉(The Gate of Firmament)                                    0.000000
#
# item_name                                     1,000 Heads Among the Trees  \
# item_name
# ! That Bastard Is Trying To Steal Our Gold !                     0.500000
# "Glow Ball" - The billiard puzzle game                           0.500000
# #SelfieTennis                                                    0.577350
# $1 Ride                                                          0.577350
# 'n Verlore Verstand                                              0.235702
# ...                                                                   ...
# the static speaks my name                                        0.500000
# theBlu                                                           0.408248
# theHunter: Primal                                                0.000000
# 侠客风云传(Tale of Wuxia)                                             0.000000
# 軒轅劍外傳穹之扉(The Gate of Firmament)                                  0.000000
#
# item_name                                     10 Second Ninja  ...  \
# item_name                                                      ...
# ! That Bastard Is Trying To Steal Our Gold !         0.707107  ...
# "Glow Ball" - The billiard puzzle game               0.353553  ...
# #SelfieTennis                                        0.408248  ...
# $1 Ride                                              0.816497  ...
# 'n Verlore Verstand                                  0.166667  ...
# ...                                                       ...  ...
# the static speaks my name                            0.353553  ...
# theBlu                                               0.288675  ...
# theHunter: Primal                                    0.408248  ...
# 侠客风云传(Tale of Wuxia)                                 0.000000  ...
# 軒轅劍外傳穹之扉(The Gate of Firmament)                      0.000000  ...
#
# item_name                                     rymdkapsel  sZone-Online  \
# item_name
# ! That Bastard Is Trying To Steal Our Gold !    0.353553      0.250000
# "Glow Ball" - The billiard puzzle game          0.707107      0.000000
# #SelfieTennis                                   0.408248      0.000000
# $1 Ride                                         0.408248      0.288675
# 'n Verlore Verstand                             0.166667      0.000000
# ...                                                  ...           ...
# the static speaks my name                       0.353553      0.500000
# theBlu                                          0.288675      0.000000
# theHunter: Primal                               0.000000      0.288675
# 侠客风云传(Tale of Wuxia)                            0.316228      0.223607
# 軒轅劍外傳穹之扉(The Gate of Firmament)                 0.000000      0.500000
#
# item_name                                     samurai_jazz  \
# item_name
# ! That Bastard Is Trying To Steal Our Gold !      0.866025
# "Glow Ball" - The billiard puzzle game            0.288675
# #SelfieTennis                                     0.333333
# $1 Ride                                           0.666667
# 'n Verlore Verstand                               0.272166
# ...                                                    ...
# the static speaks my name                         0.577350
# theBlu                                            0.471405
# theHunter: Primal                                 0.666667
# 侠客风云传(Tale of Wuxia)                              0.258199
# 軒轅劍外傳穹之扉(The Gate of Firmament)                   0.000000
#
# item_name                                     simian.interface++    stratO  \
# item_name
# ! That Bastard Is Trying To Steal Our Gold !            0.707107  0.577350
# "Glow Ball" - The billiard puzzle game                  0.707107  0.288675
# #SelfieTennis                                           0.408248  0.333333
# $1 Ride                                                 0.816497  0.666667
# 'n Verlore Verstand                                     0.333333  0.136083
# ...                                                          ...       ...
# the static speaks my name                               0.353553  0.288675
# theBlu                                                  0.577350  0.471405
# theHunter: Primal                                       0.000000  0.666667
# 侠客风云传(Tale of Wuxia)                                    0.316228  0.258199
# 軒轅劍外傳穹之扉(The Gate of Firmament)                         0.000000  0.000000
#
# item_name                                     the static speaks my name  \
# item_name
# ! That Bastard Is Trying To Steal Our Gold !                   0.500000
# "Glow Ball" - The billiard puzzle game                         0.250000
# #SelfieTennis                                                  0.288675
# $1 Ride                                                        0.288675
# 'n Verlore Verstand                                            0.235702
# ...                                                                 ...
# the static speaks my name                                      1.000000
# theBlu                                                         0.408248
# theHunter: Primal                                              0.288675
# 侠客风云传(Tale of Wuxia)                                           0.447214
# 軒轅劍外傳穹之扉(The Gate of Firmament)                                0.500000
#
# item_name                                       theBlu  theHunter: Primal  \
# item_name
# ! That Bastard Is Trying To Steal Our Gold !  0.612372           0.577350
# "Glow Ball" - The billiard puzzle game        0.408248           0.000000
# #SelfieTennis                                 0.471405           0.000000
# $1 Ride                                       0.471405           0.333333
# 'n Verlore Verstand                           0.384900           0.136083
# ...                                                ...                ...
# the static speaks my name                     0.408248           0.288675
# theBlu                                        1.000000           0.471405
# theHunter: Primal                             0.471405           1.000000
# 侠客风云传(Tale of Wuxia)                          0.547723           0.516398
# 軒轅劍外傳穹之扉(The Gate of Firmament)               0.000000           0.000000
#
# item_name                                     侠客风云传(Tale of Wuxia)  \
# item_name
# ! That Bastard Is Trying To Steal Our Gold !              0.447214
# "Glow Ball" - The billiard puzzle game                    0.447214
# #SelfieTennis                                             0.000000
# $1 Ride                                                   0.258199
# 'n Verlore Verstand                                       0.210819
# ...                                                            ...
# the static speaks my name                                 0.447214
# theBlu                                                    0.547723
# theHunter: Primal                                         0.516398
# 侠客风云传(Tale of Wuxia)                                      1.000000
# 軒轅劍外傳穹之扉(The Gate of Firmament)                           0.447214
#
# item_name                                     軒轅劍外傳穹之扉(The Gate of Firmament)
# item_name
# ! That Bastard Is Trying To Steal Our Gold !                         0.000000
# "Glow Ball" - The billiard puzzle game                               0.000000
# #SelfieTennis                                                        0.000000
# $1 Ride                                                              0.000000
# 'n Verlore Verstand                                                  0.000000
# ...                                                                       ...
# the static speaks my name                                            0.500000
# theBlu                                                               0.000000
# theHunter: Primal                                                    0.000000
# 侠客风云传(Tale of Wuxia)                                                 0.447214
# 軒轅劍外傳穹之扉(The Gate of Firmament)                                      1.000000
#
# [6941 rows x 6941 columns]

# %%
# Creando la función de recomendación de Items
def get_recommendations_by_id(item_id: int):
    # Obtener el nombre del item por el ID
    game_name = df_id.loc[df_id['item_id'] == item_id, 'item_name'].iloc[0]

    # Verificando si existen items similares en la matriz
    if game_name not in game_sim_df.index:
        return [], f"ID {item_id} has not data avalible."

    # Obteniendo la fila correspondiente al item
    game_row = game_sim_df.loc[game_name]

    # Encuentra artículos similares ordenando la fila
    similar_games = game_sim_df.dot(game_row).sort_values(ascending=False)

    # Eliminar el elemento en sí de la lista de recomendaciones
    similar_games = similar_games.drop(game_name)

    # Tome los primeros 5 juegos como recomendaciones y regrese en formato de lista
    recommendations = similar_games.nlargest(5).index.tolist()

    return 'Recomendación de artículos similares al artìculo {}'.format(item_id), recommendations

# %%
row = df_id[df_id['item_name'] == 'theHunter: Primal']
row
# Out:
#          item_id          item_name
# 1894349   322920  theHunter: Primal

# %%
get_recommendations_by_id(322920)
# Out:
# ('Recomendación de artículos similares al artìculo 322920',
#  ['Dungeon of Zolthan',
#   'Epsilon corp.',
#   'Miasmata',
#   'The Ball',
#   'Enter the Gungeon'])

# %%
dfs = [umatrix_norm, user_sim_df, df_id, game_sim_df,]

# Nombres correspondientes a cada DataFrame
names = ['umatrix_norm','user_sim', 'df_id', 'game_sim']

# Guardando los dataframes como archivos parquet para uso de la API
ut.save_to_pq(dfs, names)
# Out:
# DataFrame 'umatrix_norm' save as '../Data/parquet/umatrix_norm.parquet'
# DataFrame 'user_sim' save as '../Data/parquet/user_sim.parquet'
# DataFrame 'df_id' save as '../Data/parquet/df_id.parquet'
# DataFrame 'game_sim' save as '../Data/parquet/game_sim.parquet'

# %%
user_sim_df.to_parquet('../Data/parquet/user_sim.parquet.gz', compression='gzip', index=False)

game_sim_df.to_parquet('../Data/parquet/game_sim.parquet.gz', compression='gzip', index=False)
